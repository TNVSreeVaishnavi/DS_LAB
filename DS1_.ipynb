# %% [markdown]
# <a href="https://colab.research.google.com/github/TNVSreeVaishnavi/DS_LAB/blob/main/DS1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#Sample dataset
df = pd.DataFrame({'Age':[25,30,np.nan,40,35],
'Department':['HR','Finance','Finance',np.nan,'IT']})

df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Department'].fillna(df['Department'].mode()[0],inplace=True)
print(df)
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  32.5    Finance
# 3  40.0    Finance
# 4  35.0         IT
# /tmp/ipykernel_9707/4183666397.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)
# /tmp/ipykernel_9707/4183666397.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
#forward fill
import pandas as pd
import numpy as np
#sample dataset
df=pd.DataFrame({'Age':[25,30,np.nan,40,35],
'Department':['HR','Finance','Finance',np.nan,'IT']})
df_ffill=df.copy()
df_ffill.fillna(method='ffill',inplace=True)
print(df_ffill)
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  30.0    Finance
# 3  40.0    Finance
# 4  35.0         IT
# /tmp/ipykernel_9707/946735182.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill.fillna(method='ffill',inplace=True)

# %%
import pandas as pd
import numpy as np
# Sample dataset
df = pd.DataFrame({  'Age': [25, 30, np.nan, 40, 35],
'Department': ['HR', 'Finance', 'Finance', np.nan, 'IT']})
df_bfill = df.copy()
df_bfill.fillna(method='bfill', inplace=True)
print(df_bfill)
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  40.0    Finance
# 3  40.0         IT
# 4  35.0         IT
# /tmp/ipykernel_9707/3359675985.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill.fillna(method='bfill', inplace=True)

# %%
# Drop rows with missing values
import pandas as pd
import numpy as np

df = pd.DataFrame({  'Age': [25, 30, np.nan, 40, 35],
'Department': ['HR', 'Finance', 'Finance', np.nan, 'IT']})
df_drop_rows = df.dropna()
print("After dropping rows:\n", df_drop_rows)
# Out:
# After dropping rows:
#      Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 4  35.0         IT

# %%
# Drop columns with missing values
import pandas as pd
import numpy as np

df = pd.DataFrame({  'Age': [25, 30, np.nan, 40, 35],
'Department': ['HR', 'Finance', 'Finance', np.nan, 'IT']})
df_drop_cols = df.dropna(axis=1)
print("After dropping columns:\n", df_drop_cols)
# Out:
# After dropping columns:
#  Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
#removing duplicated
import pandas as pd
#sample dataset with duplicates
df=pd.DataFrame({'ID':[1,2,2,3,4,4],
                 'Name':['Alice','Bob','Bob','Charlie','David','David'],
                 'Age':[25,30,30,35,40,40]
})
print("Original Data:\n",df)
#Remove exact duplicates
df_exact=df.drop_duplicates()
print("\nAfter Exact Match Removal:\n",df_exact)
# Out:
# Original Data:
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# 5   4    David   40
#
# After Exact Match Removal:
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40

# %%
import pandas as pd

# Data Standardization
df = pd.DataFrame({
    'Date': ['2025-01-05', '05/01/2025', 'Jan 5, 2025', '2025.01.05']
})
df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')

print(df)
# Out:
#          Date
# 0  2025-01-05
# 1         NaN
# 2         NaN
# 3         NaN

# %%
import pandas as pd
df=pd.DataFrame({
    'Name':['Alice','BOB','charlie','DAVID']
})
#Case normalization
#df['Name_lower']=df['Name'].str.lower()
df['Name_upper']=df['Name'].str.upper()

print(df)
# Out:
#       Name Name_upper
# 0    Alice      ALICE
# 1      BOB        BOB
# 2  charlie    CHARLIE
# 3    DAVID      DAVID

# %%
import numpy as np
from scipy.spatial import distance

pointA=np.array([2,4,6])
pointB=np.array([5,1,9])

euclidean_dist=distance.euclidean(pointA,pointB)
print("Euclidean Distance:",euclidean_dist)

similarity_euclidean=1/(1+euclidean_dist)
print("Euclidean Similarity:",similarity_euclidean)
# Out:
# Euclidean Distance: 5.196152422706632
# Euclidean Similarity: 0.16139047779640892

# %%
import numpy as np
from scipy.spatial import distance

manhattan_dist=distance.cityblock(pointA,pointB)
print("Manhattan Distance:",manhattan_dist)

similarity_manhattan=1/(1+manhattan_dist)
print("Manhattan Similarity:",similarity_manhattan)
# Out:
# Manhattan Distance: 9
# Manhattan Similarity: 0.1

# %%
#its is a general form it can become manhattan when p=1
#it can become euclidean when p=2 it adds absolute values

# %%
import numpy as np
from scipy.spatial import distance
minkowski_dist_p3=distance.minkowski(pointA,pointB,p=3)
print("Minkowski Distance (p=3):",minkowski_dist_p3)

similarity_minkowski=1/(1+minkowski_dist_p3)
print("Minkowski Similarity(p=3):",similarity_minkowski)
# Out:
# Minkowski Distance (p=3): 4.3267487109222245
# Minkowski Similarity(p=3): 0.1877317767871331

# %%
import pandas as pd
from scipy.stats import pearsonr

tips=pd.read_csv("tips.csv")

corr,p_value=pearsonr(tips['total_bill'],tips['tip'])

print(f"Pearson correlation coefficient:{corr}")
print(f"P-value:{p_value}")
#this will be used when the data is not perfectly linear then we use these methods
# Out:
# Pearson correlation coefficient:0.6757341092113647
# P-value:6.692470646863279e-34

# %%
import pandas as pd
from scipy.stats import spearmanr

df=pd.DataFrame({
    'X':[10,20,30,40,50],
    'Y':[12,18,33,47,55]
})

corr_value,p_value=spearmanr(df['X'],df['Y'])
print(f"Spearman Correlation Coefficient:{corr_value}")
print(f"P-value:{p_value}")
# Out:
# Spearman Correlation Coefficient:0.9999999999999999
# P-value:1.4042654220543672e-24

# %%
def hamming_distance(str1,str2):
  if len(str1) != len(str2):
    raise ValueError("Strings must be of equal length")

  return sum(ch1 != ch2 for ch1, ch2 in zip(str1,str2))
s1="karolin"
s2="kathrin"

dist=hamming_distance(s1,s2)
print(f"Hamming Distance between '{s1}' and '{s2}': {dist}")
# Out:
# Hamming Distance between 'karolin' and 'kathrin': 3

# %%
def jaccard_index(str1, str2):
    set1, set2 = set(str1.split()), set(str2.split())
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    return len(intersection) / len(union)

# Example usage
s1 = "data science is fun"
s2 = "science makes data useful"

print("Jaccard Index:", jaccard_index(s1, s2))
# Out:
# Jaccard Index: 0.3333333333333333

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

s1="data science is fun"
s2="science makes data useful"

vectorizer = CountVectorizer().fit([s1,s2])
vectors=vectorizer.transform([s1,s2])

cos_sim=cosine_similarity
print("Cosine Similarity:",cos_sim)
# Out:
# Cosine Similarity: <function cosine_similarity at 0x78fe0d95b880>

# %%
def lcs_length(X, Y):
    m, n = len(X), len(Y)
    dp = [[0] * (n + 1) for _ in range(m + 1)]
    for i in range(m):
        for j in range(n):

            if X[i] == Y[j]:
                dp[i + 1][j + 1] = dp[i][j] + 1

            else:
                dp[i + 1][j + 1] = max(dp[i][j + 1], dp[i + 1][j])

    return dp[m][n]

seq1 = "ABCDEF"
seq2 = "AEBDF"

length = lcs_length(seq1, seq2)

print("Longest Common Subsequence Length:", length)
# Out:
# Longest Common Subsequence Length: 4

# %%
#week5
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

data=pd.DataFrame({
    'A':[10,20,30,40,50],
    'B':[5,15,25,35,45]
})
print("Before Normalization:")
print(data)
scaler=MinMaxScaler()
normalized_data=scaler.fit_transform(data)

normalized_df=pd.DataFrame(normalized_data,columns=data.columns)

print("Normalized Data (Min-Max Scaling):")
print(normalized_df)
# Out:
# Before Normalization:
#     A   B
# 0  10   5
# 1  20  15
# 2  30  25
# 3  40  35
# 4  50  45
# Normalized Data (Min-Max Scaling):
#       A     B
# 0  0.00  0.00
# 1  0.25  0.25
# 2  0.50  0.50
# 3  0.75  0.75
# 4  1.00  1.00

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
standardized_data=scaler.fit_transform(data)

standardized_df=pd.DataFrame(standardized_data,columns=data.columns)

print("\nStandardized Data (Z-score):")
print(standardized_df)
# Out:
# Standardized Data (Z-score):
#           A         B
# 0 -1.414214 -1.414214
# 1 -0.707107 -0.707107
# 2  0.000000  0.000000
# 3  0.707107  0.707107
# 4  1.414214  1.414214

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

data = pd.DataFrame({
    'Branch':['CSE','ECE','MECH','CSE','ECE']
})
encoder=LabelEncoder()
data['Encoded_Branch']=encoder.fit_transform(data['Branch'])
print(data)
# Out:
#   Branch  Encoded_Branch
# 0    CSE               0
# 1    ECE               1
# 2   MECH               2
# 3    CSE               0
# 4    ECE               1

# %%
#Week7
import pandas as pd
from sklearn.datasets import load_iris
# Load iris dataset
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target
# Map species numbers to names
df['species'] = df['species'].map({0:'setosa', 1:'versicolor', 2:'virginica'})
# Inspect
print(df.head())
print(df.info())
print("col names", df.columns)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# ...

# %%
# Numerical summary
print(df.describe())

# Categorical summary
print(df.describe(include=['object']))

# Frequency counts for a categorical column
print(df['species'].value_counts())
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
#        species
# count      150
# unique       3
# top     setosa
# freq        50
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#linechart
plt.plot(df['petal length (cm)'])
plt.xlabel("random value")
plt.ylabel("Plength")
plt.title("line chart with petal length (cm) only")
plt.show()

# %%
#linechart
plt.plot(df['sepal length (cm)'], df['petal length (cm)'])
plt.xlabel("Slength")
plt.ylabel("Plength")
plt.title("line chart with petal length (cm) vs sepal length (cm)")
plt.show()

# %%
# Histogram: distribution of values
df['sepal length (cm)'].hist()
plt.xlabel("bins")
plt.ylabel("no.of elements in each bin")
plt.title("histogram of sepal length (cm)")
plt.show()

# %%
# Plot histogram with the density curve
sns.histplot(df['sepal length (cm)'], kde=True, bins=10, color="skyblue", stat="density")

# Add labels and show
plt.title("Histogram with KDE Curve (Seaborn)")
plt.xlabel("Values")
plt.ylabel("Density")
plt.show()

# %%
# Boxplot: detect outliers
sns.boxplot(x=df['sepal length (cm)'])
plt.show()

# %%
#species boxplots
sns.boxplot(x="species", y="petal length (cm)", data=df)
plt.title("Petal Length Distribution by Species")
plt.show()

# %%
# Set the style
sns.set_theme(style="whitegrid")

# Create a bar plot showing the mean sepal length for each species
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x="species", y="sepal length (cm)", hue="species", palette="muted")

# Add descriptive labels
plt.title("Average Sepal Length by Iris Species")
plt.xlabel("Species")
plt.ylabel("Mean Sepal Length (cm)")

# Display the plot
plt.show()

# %%
sns.scatterplot(data=df, x="sepal length (cm)", y="petal length (cm)", hue="species", palette="deep")
plt.title("Sepal Length vs Sepal Width")
plt.show()

# %%
# Create a bar plot for the frequency of the three species
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x="species", hue="species", palette="Set2")

# Add descriptive labels
plt.title("Frequency Distribution of Iris Species")
plt.xlabel("Species")
plt.ylabel("Count")

# Display the plot
plt.show()

# %%
sns.violinplot(x="species", y="petal length (cm)", data=df, palette="muted")
plt.title("Petal Width Density Profile by Species")
plt.show()
# Out:
# /tmp/ipykernel_393/4164126180.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="species", y="petal length (cm)", data=df, palette="muted")

# %%
# Correlation heatmap: relationships between numerical variables
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()

# %%
# scatter plot matrix with pairplots
sns.pairplot(df, hue="species")
plt.show()

# %%
#joint plots
sns.jointplot(data=df, x="petal length (cm)", y="petal width (cm)", hue="species", kind="scatter")
plt.show()

# %%
import matplotlib.pyplot as plt
y1 =[]
y2 =[]
x = range(-100,100,10)
for i in x: y1.append(i**2)
for i in x: y2.append(-i**2)

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim(-2000, 2000)
plt.axhline(0) # horizontal line
plt.axvline(0) # vertical line

plt.savefig("quad.png")

plt.show()

# %%
import matplotlib.pyplot as plt


# heights of bars
height = [10, 24, 36, 40, 5]

# labels for bars
names = ['one','two','three','four','five']

# plotting a bar chart
c1 =['red', 'green']
c2 =['b', 'g'] # we can use this for color
plt.bar(names, height, width=0.8, color=c1)

# naming the x-axis
plt.xlabel('x - axis')
# naming the y-axis
plt.ylabel('y - axis')
# plot title
plt.title('My bar chart!')

# function to show the plot
plt.show()

# %%
import pandas as pd
X = pd.read_csv("Student_Interest_DS_ML_DL_2010_2025.csv")
X.rename(columns={'Students_Interested_Data_Science': 'Data_Science',
                  'Students_Interested_Machine_Learning': 'Machine_Learning',
                  'Students_Interested_Deep_Learning': 'Deep_Learning'}, inplace=True)
X.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_393/3604970672.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 X = pd.read_csv("Student_Interest_DS_ML_DL_2010_2025.csv")
#       3 X.rename(columns={'Students_Interested_Data_Science': 'Data_Science',
#       4                   'Students_Interested_Machine_Learning': 'Machine_Learning',
#       5                   'Students_Interested_Deep_Learning': 'Deep_Learning'}, inplace=True)
#
# ...
